# %% [markdown]
# <a href="https://colab.research.google.com/github/rhqtmfajfl/python-study/blob/master/rhqtmfajfl/python-study/colab/04_%ED%96%89%EB%A0%AC%EA%B3%BC_%EC%8B%A0%EA%B2%BD%EB%A7%8C0621.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![내그림 2021 -x114.행렬과 신경망jpg.jpg](data:image/jpeg;base64,...)

# %%
#신경망에서 가중치들의 설정으로 행렬을 구할 수 있을 까?
#두개씩 입력받는 세개 뉴런들

# 그림에서 가중치를 두개씩 받는다.

# %% [markdown]
# ![내그림 2021 -x118-행렬과 신경망 .jpg](data:image/jpeg;base64,...)
